# %% [markdown]
# # Objetivo script
# El objetivo de este script es ejecutar y probar las funciones que se van diseñando en common_help.py

# %%
import warnings
warnings.filterwarnings("ignore")
from src.common_help import *

# %%
from pypdf import (PdfReader, PdfWriter)

# %%
pdf_path = r"C:\Users\nicol\Downloads\ExtractosUnificados20250805.pdf"
reader = PdfReader(stream=pdf_path, password=dict_vars['password_extract'])

# %%
len(reader.pages)
# Out:
# 6

# %%
print(reader.pages[1].extract_text())
# Out:
# Hoja 2 de 6
#    PCG272343
# BANCO DE OCCIDENTE S.A.
# NICOLAS GIL LUGO
# CR 1 BIS # 56 - 161 TRR D AP 401 BR TORRES DE COMFANDI
# CALI - VALLE DEL CAUCA
# CUENTA No. 010-14302-2
# FECHA DE CORTE: 31/07/2025
# Hola, tu cuenta de ahorros ahora se llama KUBO. En su cara Kubo Rentable, tu dinero empieza a crecer
# al 7% E.A. desde el primer día. Activa esta opción en tu Portal Transaccional.
# RESUMEN
# SALDO ANTERIOR 7,136,419.77
# + 31 CREDITOS 7,059,317.39
# - 0 DEBITOS 0.00
# SALDO ACTUAL 14,195,737.16
# SALDO PROMEDIO 10,660,236.45
# NIT: 890.300.279-4
# DIA TRANSACCIÓN IDENT. DEBITOS CREDITOS SALDO
# 03 INTERESES LIQUIDADOS A198422 0.00 1,323.66 7,137,743.43
# 03 INTERESES LIQUIDADOS A198416 0.00 1,323.90 7,139,067.33
# 04 INTERESES LIQUIDADOS A957842 0.00 1,324.15 7,140,391.48
# 05 INTERESES LIQUIDADOS A908906 0.00 1,324.40 7,141,715.88
# 06 INTERESES LIQUIDADOS A838605 0.00 1,324.64 7,143,040.52
# 09 INTERESES LIQUIDADOS A802995 0.00 1,324.89 7,144,365.41
# 09 INTERESES LIQUIDADOS A802981 0.00 1,325.13 7,145,690.54
# 09 INTERESES LIQUIDADOS A802989 0.00 1,325.38 7,147,015.92
# 10 INTERESES LIQUIDADOS A130101 0.00 1,325.62 7,148,341.54
# 11 INTERESES LIQUIDADOS A007292 0.00 1,325.87 7,149,667.41
# 12 INTERESES LIQUIDADOS A788289 0.00 1,326.12 7,150,993.53
# 13 INTERESES LIQUIDADOS A597952 0.00 1,326.36 7,152,319.89
# 16 TRANSF ENTRE CTAS OCCIDENTE POR INTERNET A576334 0.00 7,000,000.00 14,152,319.89
# 16 INTERESES LIQUIDADOS A574856 0.00 1,326.61 14,153,646.50
# 16 INTERESES LIQUIDADOS A574862 0.00 1,326.85 14,154,973.35
# 16 INTERESES LIQUIDADOS A572820 0.00 1,327.10 14,156,300.45
# 17 INTERESES LIQUIDADOS A975987 0.00 2,625.70 14,158,926.15
# 18 INTERESES LIQUIDADOS A805883 0.00 2,626.19 14,161,552.34
# 19 INTERESES LIQUIDADOS A579239 0.00 2,626.68 14,164,179.02
# 20 INTERESES LIQUIDADOS A352398 0.00 2,627.16 14,166,806.18
# 24 INTERESES LIQUIDADOS A243551 0.00 2,627.65 14,169,433.83
# 24 INTERESES LIQUIDADOS A242763 0.00 2,628.14 14,172,061.97
# 24 INTERESES LIQUIDADOS A245889 0.00 2,628.63 14,174,690.60
# 24 INTERESES LIQUIDADOS A243881 0.00 2,629.11 14,177,319.71
# 25 INTERESES LIQUIDADOS A775362 0.00 2,629.60 14,179,949.31
# 26 INTERESES LIQUIDADOS A778670 0.00 2,630.09 14,182,579.40
# 27 INTERESES LIQUIDADOS A547660 0.00 2,630.58 14,185,209.98
# 27 INTERESES LIQUIDADOS A052508 0.00 2,631.06 14,187,841.04
# 27 INTERESES LIQUIDADOS A052499 0.00 2,631.55 14,190,472.59
# 27 INTERESES LIQUIDADOS A059437 0.00 2,632.04 14,193,104.63
# 27 INTERESES LIQUIDADOS A058575 0.00 2,632.53 14,195,737.16
# ESTE PRODUCTO CUENTA CON SEGURO DE DEPÓSITOS. Cualquier Inconformidad con este extracto favor comunicarla a la Revisoría Fiscal KPMG S.A.S., al buzón co-fmbanco_occidente@kpmg.com *ESOS CARGOS ESTAN SUJETOS A LA CONTRIBUCIÓN DEL  4 X MIL.
# Consultas y trámite de requerimientos: Línea de Servicio al Cliente 01 8000 51 4652, Bogotá 601 3902058, Cali 602 4851113, Medellín 604 6052020, Barranquilla 605 3869772, URL: https://contactenos.bancodeoccidente.com.co.
# Defensor del Consumidor Financiero: LINA MARÍA ZORRO CERÓN Carrera 7#71 -52 Torre A, Piso 1 Bogotá. Tel. 601 7462060, Ext.15318, Celular: 315 5704405, defensoriacliente@bancodeoccidente.com.co
# Extracto - CUENTA AHORROS
# Las cuentas de pensionados tendrán una
# tasa del 0.05% E.A para cualquier monto.
# *
# *
# Para montos mayores a $3.000.000.001 el Banco
# podrá acordar con cada cliente convenios especiales.
# Vigencia: del 01 al 31 de Julio del 2025.
# SALDO DIARIO CUENTA DE
# NÓMINA Y PENSIÓN TASA E.A
# De $0                    a   $5.000.000
# De $5.000.001      a   $20.000.000
# De $20.000.001    a   $50.000.000
# De $50.000.001    a   $100.000.000
# De $100.000.001  a   $3.000.000.000
# 0,01%
# 0,01%
# 0,01%
# 0,01%
# 0,01%
# SALDO DIARIO TASA E.A
# De $0                    a   $5.000.000
# De $5.000.001      a   $20.000.000
# De $20.000.001    a   $50.000.000
# De $50.000.001    a   $100.000.000
# De $100.000.001  a   $3.000.000.000
# 0,01%
# 0,01%
# 0,05%
# 0,05%
# 0.10%
