# %% [markdown]
# # Objetivo script
# El objetivo de este script es ejecutar y probar las funciones que se van diseñando en common_help.py

# %%
import warnings
warnings.filterwarnings("ignore")
from src.common_help import *

# %%
pdf_to_image(pdf_path=r"C:\Users\nicol\OneDrive\Escritorio\Ejemplo\20250521.pdf", num_pages=1)
# Out:
# Saving image: C:\Users\nicol\OneDrive\Escritorio\Ejemplo\20250521.png
