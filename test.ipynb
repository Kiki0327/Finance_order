# %% [markdown]
# # Objetivo script
# El objetivo de este script es ejecutar y probar las funciones que se van diseñando en common_help.py

# %%
import warnings
warnings.filterwarnings("ignore")
import os
from src.common_help import *

# %%
path = "C:/Users/nicol/Downloads/CuentaNu_AC_94255723.pdf"
password = "94255723"
decrypt_pdf(pdf_path=path, password=password)
# Out:
# 'C:/Users/nicol/Downloads/CuentaNu_AC_94255723.pdf'

# %%
path = "G:/Mi unidad/Documentos/Finanzas/Vivienda/VERDANT/Separacion/"
pdfs = os.listdir(path)
pdfs = [file for file in pdfs if "ExtractoOccidente" in file]
for i in range(len(pdfs)):
    pdfs[i] = path + pdfs[i]
pdfs
# Out:
# ['G:/Mi unidad/Documentos/Finanzas/Vivienda/VERDANT/Separacion/ExtractoOccidente (2).pdf',
#  'G:/Mi unidad/Documentos/Finanzas/Vivienda/VERDANT/Separacion/ExtractoOccidente (1).pdf',
#  'G:/Mi unidad/Documentos/Finanzas/Vivienda/VERDANT/Separacion/ExtractoOccidente.pdf']

# %%
join_pdfs(pdfs,path+"/ExtractoOccidente.pdf")

# %%
pdf_to_image(pdf_path="C:/Users/nicol/Downloads/certificado_fundamentos_python.pdf")
# Out:
# Saving image: C:/Users/nicol/Downloads/certificado_fundamentos_python.png
